# %% [markdown]
# # Day 11 - Modules
#
# **Concepts covered:**
#
# - Importing built-in modules
# - Creating and importing your own module
# - from ... import ...
#
# ---

# %% [markdown]
# ## Examples

# %%
import math
print(math.sqrt(16))
# create a small module: utils.py with a function greet(name)
# Out:
# 4.0

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Use math module to compute ceil and floor.

# %% [markdown]
# ## Solutions

# %%
import math
print(math.ceil(2.3), math.floor(2.7))
# Out:
# 3 2
