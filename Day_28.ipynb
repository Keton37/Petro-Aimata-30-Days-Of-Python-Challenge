# %% [markdown]
# # Day 28 - APIs
#
# **Concepts covered:**
#
# - Requests to REST APIs
# - Parsing JSON responses
# - Authentication basics
#
# ---

# %% [markdown]
# ## Examples

# %%
import requests
url = "https://api.agify.io?name=peter"
r = requests.get(url)
print(r.json())
# Out:
# {'count': 169145, 'name': 'peter', 'age': 70}

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Fetch JSON data from a public API and print a field.

# %% [markdown]
# ## Solutions

# %%
import requests
r = requests.get("https://api.agify.io?name=petro")
print(r.json())
# Out:
# {'count': 1533, 'name': 'petro', 'age': 56}
