# %% [markdown]
# # Day 20 - JSON
#
# **Concepts covered:**
#
# - json.dumps, json.loads
# - Reading & writing JSON files
#
# ---

# %% [markdown]
# ## Examples

# %%
import json
person = {"name":"Petro","age":20}
s = json.dumps(person)
print(s)
with open("person.json","w") as f:
    json.dump(person,f, indent=2)
# Out:
# {"name": "Petro", "age": 20}

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Convert a dictionary to JSON and save to file.

# %% [markdown]
# ## Solutions

# %%
import json
d = {"a":1}
with open("d.json","w") as f:
    json.dump(d,f)
