# %% [markdown]
# # Day 06 - Sets
#
# **Concepts covered:**
#
# - Unique elements
# - Set operations: union, intersection, difference
# - When to use sets
#
# ---

# %% [markdown]
# ## Examples

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create two sets of numbers and compute union and intersection.

# %% [markdown]
# ## Solutions

# %%
a = {1,2,3}
b = {3,4,5}
print(a | b)
print(a & b)
# Out:
# {1, 2, 3, 4, 5}
# {3}
