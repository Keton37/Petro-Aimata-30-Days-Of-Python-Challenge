# %% [markdown]
# # Day 02 - Variables and Built-in Functions
#
# **Concepts covered:**
#
# - Variable naming
# - Data types (int, float, str, bool)
# - len(), type(), casting
#
# ---

# %% [markdown]
# ## Examples

# %%
x = 10
y = 3.14
name = "Petro Long'or Aimata"
is_student = True
print(type(x), type(y), type(name), type(is_student))
print(len(name))
# casting
s = "123"
num = int(s) + 10
print(num)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# 20
# 133

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create variables for your name, age, country and print their types.
# **Exercise 2:** Convert a numeric string to int and add 5.

# %% [markdown]
# ## Solutions

# %%
name = "Petro Long'or Aimata"
age = 20
country = "Kenya"
print(type(name), type(age), type(country))
s = "7"
print(int(s) + 5)
# Out:
# <class 'str'> <class 'int'> <class 'str'>
# 12
