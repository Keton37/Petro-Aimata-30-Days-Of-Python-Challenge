# %% [markdown]
# # Day 19 - Date & Time
#
# **Concepts covered:**
#
# - datetime module
# - now(), strftime, parsing dates
#
# ---

# %% [markdown]
# ## Examples

# %%
from datetime import datetime
now = datetime.now()
print(now)
print(now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2025-12-07 16:09:01.275268
# 2025-12-07 16:09:01

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Print today's date in YYYY-MM-DD format.

# %% [markdown]
# ## Solutions

# %%
from datetime import date
print(date.today().isoformat())
# Out:
# 2025-12-07
