# %% [markdown]
# # Day 21 - Virtual Environments
#
# **Concepts covered:**
#
# - venv
# - pip install
# - requirements.txt
#
# ---

# %% [markdown]
# ## Examples

# %%
# In terminal, run the following commands to set up a virtual environment and install pandas:
# python -m venv venv
# venv\Scripts\activate    (Windows)
# pip install pandas

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create a venv and install pandas

# %% [markdown]
# ## Solutions

# %%
# Below are my solutions for the above exercise that I will paste to the terminal:
# python -m venv venv
#.\venv\Scripts\Activate.ps1
#pip install pandas
#pip freeze > requirements.txt

# I decided to keep it commented so that there'll be no errors when running it here.
