# %% [markdown]
# # Day 15 - Classes & Objects
#
# **Concepts covered:**
#
# - Defining classes
# - Constructors (__init__)
# - Methods and attributes
#
# ---

# %% [markdown]
# ## Examples

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        return f"Hello, I'm {self.name} and I'm {self.age}"
p = Person("Petro", 20)
print(p.greet())
# Out:
# Hello, I'm Petro and I'm 20

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create a Person class with name and age and a greet method.

# %% [markdown]
# ## Solutions

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
p=Person("Petro",20)
print(p.name,p.age)
# Out:
# Petro 20
