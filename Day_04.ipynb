# %% [markdown]
# # Day 04 - Lists
#
# **Concepts covered:**
#
# - Creating lists
# - Indexing & slicing
# - List methods (append, remove, insert, pop)
# - Iterating lists
#
# ---

# %% [markdown]
# ## Examples

# %%
fruits = ["apple", "banana", "mango", "orange"]
fruits.append("pineapple")
print(fruits)
print(fruits[0], fruits[-1])
for f in fruits:
    print(f)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'pineapple']
# apple pineapple
# apple
# banana
# mango
# orange
# pineapple

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create a list of 5 fruits and add two more.
# **Exercise 2:** Remove the second item and print the list.

# %% [markdown]
# ## Solutions

# %%
fruits = ["apple","banana","mango","orange","grape"]
print(fruits)
fruits.append("pineapple")
fruits.append("pear")
print(fruits)
fruits.pop(1)
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'grape']
# ['apple', 'banana', 'mango', 'orange', 'grape', 'pineapple', 'pear']
# ['apple', 'mango', 'orange', 'grape', 'pineapple', 'pear']
