# %% [markdown]
# # Day 09 - Loops
#
# **Concepts covered:**
#
# - for, while loops
# - break, continue
# - iterating with range()
#
# ---

# %% [markdown]
# ## Examples

# %%
total = 0
for i in range(1,101):
    total += i
print(total)
# while loop
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 5050
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Sum numbers from 1 to 100 using a loop.

# %% [markdown]
# ## Solutions

# %%
print(sum(range(1,101)))
# Out:
# 5050
