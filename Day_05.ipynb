# %% [markdown]
# # Day 05 - Tuples
#
# **Concepts covered:**
#
# - Immutable sequences
# - Tuple packing & unpacking
# - When to use tuples
#
# ---

# %% [markdown]
# ## Examples

# %%
coords = (10.0, 20.0)
x, y = coords
print(x, y)
single = (5,)  # single element tuple
print(type(single))
# Out:
# 10.0 20.0
# <class 'tuple'>

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create a tuple of 5 countries and unpack the first two.

# %% [markdown]
# ## Solutions

# %%
countries = ("Kenya","Uganda","Tanzania","Rwanda","Ethiopia")
a,b, *rest = countries
print(a,b)
# Out:
# Kenya Uganda
