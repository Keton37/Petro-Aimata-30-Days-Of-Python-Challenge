# %% [markdown]
# # Day 18 - Regular Expressions
#
# **Concepts covered:**
#
# - re module
# - search, findall, sub
# - pattern basics
#
# ---

# %% [markdown]
# ## Example

# %%
import re
text = "Call me at 0712345678 or 0723456789"
phones = re.findall(r"07\d{8}", text)
print(phones)
# Out:
# ['0712345678', '0723456789']

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Extract all digits from a string.

# %% [markdown]
# ## Solutions

# %%
import re
s = "Order 123, ref 456"
print(re.findall(r"\d+", s))
# Out:
# ['123', '456']
