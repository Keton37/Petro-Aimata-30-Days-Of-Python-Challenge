# %% [markdown]
# # Day 10 - Functions
#
# **Concepts covered:**
#
# - Defining functions
# - Parameters, return values
# - Default and keyword arguments
#
# ---

# %% [markdown]
# ## Examples

# %%
def add(a,b=0):
    return a + b
print(add(5,3))
print(add(7))
# Out:
# 8
# 7

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Create a function that adds two numbers and returns result.

# %% [markdown]
# ## Solutions

# %%
def add(a,b):
    return a+b
print(add(2,3))
# Out:
# 5
