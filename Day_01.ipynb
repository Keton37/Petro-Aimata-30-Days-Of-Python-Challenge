# %% [markdown]
# # Day 01 - Introduction to Python
#
# **Concepts covered:**
#
# - What is Python?
# - Why learn Python?
# - Installing Python and running a REPL / Jupyter Notebook
# - Your first Python program: printing and comments
# - Variables and basic data types

# %% [markdown]
# ## Example

# %%
# First Python program
print("Welcome to 30 Days of Python, Petro Long'or Aimata!")
# Basic variables
name = "Petro Long'or Aimata"
age = 20
country = "Kenya"
print(f"My name is {name}. I am {age} years old and I live in {country}.")
# Out:
# Welcome to 30 Days of Python, Petro Long'or Aimata!
# My name is Petro Long'or Aimata. I am 20 years old and I live in Kenya.

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Print your name and age.
# **Exercise 2:** Write a comment that describes Python in one sentence.
# **Exercise 3:** Assign your country to a variable and print it.

# %% [markdown]
# ## Solutions

# %%
# Solution for the above exercises
print("Petro Long'or Aimata")
# comment: Python is a high-level, interpreted programming language.
country = "Kenya"
print(country)
# Out:
# Petro Long'or Aimata
# Kenya
