# %% [markdown]
# # Day 23 - Pandas Basics
#
# **Concepts covered:**
#
# - DataFrame, Series
# - read_csv, head, describe
# - selection and filtering
#
# ---

# %% [markdown]
# ## Examples

# %%
import pandas as pd
# Using the Student DSA.csv file from my OneDrive
df = pd.read_csv("C:/Users/User/OneDrive - Mpesa Foundation Academy/Student DSA.csv")
print(df.head())
print(df.describe())
# Out:
#       Name                 Major   Age     Hobby  Unnamed: 4
# 0    David          Data Science  21.0    Hiking         NaN
# 1    Petro                    IR  19.0   Singing         NaN
# 2  Jackson                   APT  18.0  Shooting         NaN
# 3   Richie  Software Development   NaN  Swimming         NaN
# 4     John                    IR  18.0   Surfing         NaN
#              Age  Unnamed: 4
# count   5.000000         0.0
# mean   19.800000         NaN
# std     2.167948         NaN
# min    18.000000         NaN
# 25%    18.000000         NaN
# 50%    19.000000         NaN
# 75%    21.000000         NaN
# max    23.000000         NaN

# %% [markdown]
# ## Exercises
#
# **Exercise 1:** Load a CSV and show first 5 rows.

# %% [markdown]
# ## Solutions (Example answers)
#
# Edit or hide these when practicing.

# %%
import pandas as pd
df = pd.read_csv("C:/Users/User/OneDrive - Mpesa Foundation Academy/Student DSA.csv")
print(df.head())
# Out:
#       Name                 Major   Age     Hobby  Unnamed: 4
# 0    David          Data Science  21.0    Hiking         NaN
# 1    Petro                    IR  19.0   Singing         NaN
# 2  Jackson                   APT  18.0  Shooting         NaN
# 3   Richie  Software Development   NaN  Swimming         NaN
# 4     John                    IR  18.0   Surfing         NaN
